# %%
from huggingface_hub import login
import os
login(token=os.getenv("HF_TOKEN"))
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from transformers import AutoTokenizer

# %%
input = "සිංහලෙන් කතා කරන්න පුළුවන් නම් කුඹුරු කරන එක ගැන දන්න දේවල් කියන්න. පළිබෝධ සහ රෝග පිළිබඳ ඔබේ දැනුම ඉස්මතු කිරීමට වග බලා ගන්න."

# %%
def tokenize_with_model(model):
  tokenizer = AutoTokenizer.from_pretrained(model)
  tokenized_output = tokenizer.tokenize(input)
  return len(tokenized_output), tokenized_output

# %%
print(tokenize_with_model("MBZUAI/bactrian-x-llama-13b-merged"))
# Out:
# (228, ['▁', '<0xE0>', '<0xB7>', '<0x83>', 'ි', '<0xE0>', '<0xB6>', '<0x82>', '<0xE0>', '<0xB7>', '<0x84>', '<0xE0>', '<0xB6>', '<0xBD>', '<0xE0>', '<0xB7>', '<0x99>', 'න', '්', '▁', 'ක', '<0xE0>', '<0xB6>', '<0xAD>', 'ා', '▁', 'ක', 'ර', 'න', '්', 'න', '▁', '<0xE0>', '<0xB6>', '<0xB4>', '<0xE0>', '<0xB7>', '<0x94>', '<0xE0>', '<0xB7>', '<0x85>', '<0xE0>', '<0xB7>', '<0x94>', 'ව', 'න', '්', '▁', 'න', 'ම', '්', '▁', 'ක', '<0xE0>', '<0xB7>', '<0x94>', '<0xE0>', '<0xB6>', '<0xB9>', '<0xE0>', '<0xB7>', '<0x94>', 'ර', '<0xE0>', '<0xB7>', '<0x94>', '▁', 'ක', 'ර', 'න', '▁', '<0xE0>', '<0xB6>', '<0x91>', 'ක', '▁', '<0xE0>', '<0xB6>', '<0x9C>', '<0xE0>', '<0xB7>', '<0x90>', 'න', '▁', '<0xE0>', '<0xB6>', '<0xAF>', 'න', '්', 'න', '▁', '<0xE0>', '<0xB6>', '<0xAF>', '<0xE0>', '<0xB7>', '<0x9A>', 'ව', '<0xE0>', '<0xB6>', '<0xBD>', '්', '▁', 'ක', 'ි', '<0xE0>', '<0xB6>', '<0xBA>', 'න', '්', 'න', '.', '▁', '<0xE0>', '<0xB6>', '<0xB4>', '<0xE0>', '<0xB7>', '<0x85>', 'ි', '<0xE0>', '<0xB6>', '<0xB6>', '
# ...

# %%
print(tokenize_with_model("microsoft/Phi-3-small-8k-instruct"))
# Out:
# ...
# The repository for microsoft/Phi-3-small-8k-instruct contains custom code which must be executed to correctly load the model. You can inspect the repository content at https://hf.co/microsoft/Phi-3-small-8k-instruct.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# ...

# %%
print(tokenize_with_model("mistralai/Mistral-7B-v0.3"))
# Out:
# (220, ['▁', 'ස', 'ි', '<0xE0>', '<0xB6>', '<0x82>', '<0xE0>', '<0xB7>', '<0x84>', '<0xE0>', '<0xB6>', '<0xBD>', '<0xE0>', '<0xB7>', '<0x99>', 'න', '්', '▁', 'ක', '<0xE0>', '<0xB6>', '<0xAD>', 'ා', '▁', 'ක', 'ර', 'න', '්', 'න', '▁', '<0xE0>', '<0xB6>', '<0xB4>', '<0xE0>', '<0xB7>', '<0x94>', '<0xE0>', '<0xB7>', '<0x85>', '<0xE0>', '<0xB7>', '<0x94>', 'ව', 'න', '්', '▁', 'න', 'ම', '්', '▁', 'ක', '<0xE0>', '<0xB7>', '<0x94>', '<0xE0>', '<0xB6>', '<0xB9>', '<0xE0>', '<0xB7>', '<0x94>', 'ර', '<0xE0>', '<0xB7>', '<0x94>', '▁', 'ක', 'ර', 'න', '▁', '<0xE0>', '<0xB6>', '<0x91>', 'ක', '▁', '<0xE0>', '<0xB6>', '<0x9C>', '<0xE0>', '<0xB7>', '<0x90>', 'න', '▁', '<0xE0>', '<0xB6>', '<0xAF>', 'න', '්', 'න', '▁', '<0xE0>', '<0xB6>', '<0xAF>', '<0xE0>', '<0xB7>', '<0x9A>', 'ව', '<0xE0>', '<0xB6>', '<0xBD>', '්', '▁', 'ක', 'ි', 'ය', 'න', '්', 'න', '.', '▁', '<0xE0>', '<0xB6>', '<0xB4>', '<0xE0>', '<0xB7>', '<0x85>', 'ි', '<0xE0>', '<0xB6>', '<0xB6>', '<0xE0>', '<0xB7>', '<0x9D>', '<0xE0>', '<0xB6>', '
# ...

# %%
print(tokenize_with_model("bigscience/bloomz-7b1-mt"))
# Out:
# (206, ['à·', 'ĥ', 'à·', 'Ĵ', 'à¶', 'Ĥ', 'à·', 'Ħ', 'à¶', '½', 'à·', 'Ļ', 'à¶', '±', 'à·', 'Ĭ', 'Ġà¶', 'ļ', 'à¶', 'Ń', 'à·', 'ı', 'Ġà¶', 'ļ', 'à¶', '»', 'à¶', '±', 'à·', 'Ĭ', 'à¶', '±', 'Ġà¶', '´', 'à·', 'Ķ', 'à·', 'ħ', 'à·', 'Ķ', 'à·', 'Ģ', 'à¶', '±', 'à·', 'Ĭ', 'Ġà¶', '±', 'à¶', '¸', 'à·', 'Ĭ', 'Ġà¶', 'ļ', 'à·', 'Ķ', 'à¶', '¹', 'à·', 'Ķ', 'à¶', '»', 'à·', 'Ķ', 'Ġà¶', 'ļ', 'à¶', '»', 'à¶', '±', 'Ġà¶', 'ĳ', 'à¶', 'ļ', 'Ġà¶', 'ľ', 'à·', 'Ĳ', 'à¶', '±', 'Ġà¶', '¯', 'à¶', '±', 'à·', 'Ĭ', 'à¶', '±', 'Ġà¶', '¯', 'à·', 'ļ', 'à·', 'Ģ', 'à¶', '½', 'à·', 'Ĭ', 'Ġà¶', 'ļ', 'à·', 'Ĵ', 'à¶', 'º', 'à¶', '±', 'à·', 'Ĭ', 'à¶', '±', '.', 'Ġà¶', '´', 'à·', 'ħ', 'à·', 'Ĵ', 'à¶', '¶', 'à·', 'Ŀ', 'à¶', '°', 'Ġà', '·', 'ĥ', 'à·', 'Ħ', 'Ġà¶', '»', 'à·', 'Ŀ', 'à¶', 'ľ', 'Ġà¶', '´', 'à·', 'Ĵ', 'à·', 'ħ', 'à·', 'Ĵ', 'à¶', '¶', 'à¶', '³', 'Ġà¶', 'Ķ', 'à¶', '¶', 'à·', 'ļ', 'Ġà¶', '¯', 'à·', 'Ĳ', 'à¶', '±', 'à·', 'Ķ', 'à¶', '¸', 'Ġà¶', 'ī', 'à·', 'ĥ', 'à·', 'Ĭ', 'à¶', '¸', 'à¶', 'Ń', 'à·', 'Ķ', 'Ġà¶', 'ļ', 'à·', 
# ...

# %%
print(tokenize_with_model("google/gemma-2b"))
# Out:
# tokenizer_config.json:   0%|          | 0.00/33.6k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# (103, ['ස', 'ි', 'ං', 'හ', 'ල', 'ෙ', 'න්', '▁ක', 'ත', 'ා', '▁ක', 'ර', 'න්', 'න', '▁ප', 'ු', 'ළ', 'ු', 'ව', 'න්', '▁න', 'ම', '්', '▁ක', 'ු', 'ඹ', 'ු', 'ර', 'ු', '▁ක', 'ර', 'න', '▁', 'එ', 'ක', '▁', 'ග', 'ැ', 'න', '▁ද', 'න්', 'න', '▁ද', 'ේ', 'ව', 'ල', '්', '▁ක', 'ිය', 'න්', 'න', '.', '▁ප', 'ළ', 'ි', 'බ', 'ෝ', 'ධ', '▁ස', 'හ', '▁', 'ර', 'ෝ', 'ග', '▁ප', 'ි', 'ළ', 'ි', 'බ', 'ඳ', '▁', 'ඔ', 'බ', 'ේ', '▁ද', 'ැ', 'න', 'ු', 'ම', '▁', 'ඉ', 'ස', '්', 'ම', 'ත', 'ු', '▁ක', 'ි', 'ර', 'ී', 'ම', 'ට', '▁ව', 'ග', '▁', 'බ', 'ල', 'ා', '▁', 'ග', 'න්', 'න', '.'])

# %%
print(tokenize_with_model("google/paligemma-3b-pt-224"))
# Out:
# tokenizer_config.json:   0%|          | 0.00/40.0k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.26M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/607 [00:00<?, ?B/s]
# (103, ['ස', 'ි', 'ං', 'හ', 'ල', 'ෙ', 'න්', '▁ක', 'ත', 'ා', '▁ක', 'ර', 'න්', 'න', '▁ප', 'ු', 'ළ', 'ු', 'ව', 'න්', '▁න', 'ම', '්', '▁ක', 'ු', 'ඹ', 'ු', 'ර', 'ු', '▁ක', 'ර', 'න', '▁', 'එ', 'ක', '▁', 'ග', 'ැ', 'න', '▁ද', 'න්', 'න', '▁ද', 'ේ', 'ව', 'ල', '්', '▁ක', 'ිය', 'න්', 'න', '.', '▁ප', 'ළ', 'ි', 'බ', 'ෝ', 'ධ', '▁ස', 'හ', '▁', 'ර', 'ෝ', 'ග', '▁ප', 'ි', 'ළ', 'ි', 'බ', 'ඳ', '▁', 'ඔ', 'බ', 'ේ', '▁ද', 'ැ', 'න', 'ු', 'ම', '▁', 'ඉ', 'ස', '්', 'ම', 'ත', 'ු', '▁ක', 'ි', 'ර', 'ී', 'ම', 'ට', '▁ව', 'ග', '▁', 'බ', 'ල', 'ා', '▁', 'ග', 'න්', 'න', '.'])

# %%
print(tokenize_with_model("CohereForAI/aya-101"))
# Out:
# tokenizer_config.json:   0%|          | 0.00/833 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# (43, ['▁', 'සිංහල', 'ෙන්', '▁කතා', '▁කරන්න', '▁පුළුවන්', '▁', 'නම්', '▁කු', 'ඹ', 'ුරු', '▁කරන', '▁එක', '▁ගැන', '▁දන්න', '▁දේව', 'ල්', '▁කියන්න', '.', '▁ප', 'ළි', 'බෝ', 'ධ', '▁සහ', '▁ර', 'ෝග', '▁පිළි', 'බ', 'ඳ', '▁ඔ', 'බේ', '▁දැන', 'ුම', '▁ඉස්', 'ම', 'තු', '▁කිරීම', 'ට', '▁වග', '▁බ', 'ලා', '▁ගන්න', '.'])

# %%
print(tokenize_with_model("google/mt5-small"))
# Out:
# tokenizer_config.json:   0%|          | 0.00/82.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/553 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# ...

# %%
print(tokenize_with_model("bigscience/mt0-xl"))
# Out:
# tokenizer_config.json:   0%|          | 0.00/430 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/74.0 [00:00<?, ?B/s]
# (43, ['▁', 'සිංහල', 'ෙන්', '▁කතා', '▁කරන්න', '▁පුළුවන්', '▁', 'නම්', '▁කු', 'ඹ', 'ුරු', '▁කරන', '▁එක', '▁ගැන', '▁දන්න', '▁දේව', 'ල්', '▁කියන්න', '.', '▁ප', 'ළි', 'බෝ', 'ධ', '▁සහ', '▁ර', 'ෝග', '▁පිළි', 'බ', 'ඳ', '▁ඔ', 'බේ', '▁දැන', 'ුම', '▁ඉස්', 'ම', 'තු', '▁කිරීම', 'ට', '▁වග', '▁බ', 'ලා', '▁ගන්න', '.'])

# %%
print(tokenize_with_model("Qwen/Qwen1.5-1.8B"))
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ...

# %%
print(tokenize_with_model("deepseek-ai/DeepSeek-V2-Chat"))
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.28k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/4.61M [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ...

# %%
print(tokenize_with_model("01-ai/Yi-1.5-34B-Chat"))
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.67k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/1.03M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.60M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/567 [00:00<?, ?B/s]
# ...

# %%
print(tokenize_with_model("flax-community/Sinhala-gpt2"))
# Out:
# tokenizer_config.json:   0%|          | 0.00/218 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/928k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.30M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# ...
